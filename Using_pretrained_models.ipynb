# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshh670/100_days_of_DeepLearning/blob/main/Using_pretrained_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# In this notebook we will be using a pre-trained model called ResNet.

# %%
import tensorflow as tf
from tensorflow import keras
from keras import applications
from keras.applications.resnet50 import preprocess_input,decode_predictions
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
import numpy as np

# %%
model=ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
cat_path='/content/Cat.webp'
dog_path='/content/Dog.webp'

# %%
img=image.load_img(cat_path,target_size=(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img=image.img_to_array(img)
img.shape
# Out:
# (224, 224, 3)

# %%
img=np.expand_dims(img,axis=0)
img.shape
# Adding the batch dimension.
# Out:
# (1, 224, 224, 3)

# %%
img=preprocess_input(img)
img.shape
# Out:
# (1, 224, 224, 3)

# %%
pred=model.predict(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step

# %%
decode_predictions(pred)
# Out:
# [[('n02124075', 'Egyptian_cat', np.float32(0.33846286)),
#   ('n04209239', 'shower_curtain', np.float32(0.07275856)),
#   ('n02123159', 'tiger_cat', np.float32(0.06301469)),
#   ('n03958227', 'plastic_bag', np.float32(0.051343)),
#   ('n02127052', 'lynx', np.float32(0.033394318))]]
