# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshh670/100_days_of_DeepLearning/blob/main/Batch_normalisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# In this notebook we will study about batch normalisation. We will be comparing two models: One is batch-normalised and the other is not.
# Batch normalising is just normalising the inner activations from the nodes in the hidden layer just as we normalize the inputs.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from matplotlib import pyplot as pyplot
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_moons

# %% [markdown]
# # Data Generation

# %%
x,y=make_moons(noise=0.12,random_state=42)
plt.scatter(x[:,0],x[:,1],c=y)

# %%
#model1
model1=Sequential()
model1.add(Dense(3,input_dim=2,activation='relu'))
model1.add(Dense(2,activation='relu'))
model1.add(Dense(1,activation='sigmoid'))
model1.compile(loss='binary_crossentropy',optimizer='adam',metrics=['Accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history1=model1.fit(x,y,epochs=200,validation_split=0.2)
# Out:
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - Accuracy: 0.4195 - loss: 0.7164 - val_Accuracy: 0.3500 - val_loss: 0.6978
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - Accuracy: 0.3977 - loss: 0.7232 - val_Accuracy: 0.3500 - val_loss: 0.6975
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - Accuracy: 0.4133 - loss: 0.7139 - val_Accuracy: 0.3500 - val_loss: 0.6971
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - Accuracy: 0.3820 - loss: 0.7214 - val_Accuracy: 0.3500 - val_loss: 0.6968
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - Accuracy: 0.4211 - loss: 0.7157 - val_Accuracy: 0.3500 - val_loss: 0.6965
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - Accuracy: 0.4227 - loss: 0.7138 - val_Accuracy: 0.3500 - val_loss: 0.6961
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - Accuracy: 0.3953 - loss: 0.7123 - val_Accuracy: 0.3500 - val_loss: 0.6958
# Epoch 8/200
# ...

# %%
# model2
from keras.layers import BatchNormalization
model2=Sequential()
model2.add(Dense(3,input_dim=2,activation='relu'))
model2.add(BatchNormalization())
model2.add(Dense(2,activation='relu'))
model2.add(BatchNormalization())
model2.add(Dense(1,activation='sigmoid'))
model2.compile(loss='binary_crossentropy',optimizer='adam',metrics=['Accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history2=model2.fit(x,y,epochs=200,validation_split=0.2)
# Out:
# Epoch 1/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 157ms/step - Accuracy: 0.8039 - loss: 0.4444 - val_Accuracy: 0.8000 - val_loss: 0.5165
# Epoch 2/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - Accuracy: 0.8164 - loss: 0.4454 - val_Accuracy: 0.8000 - val_loss: 0.5142
# Epoch 3/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - Accuracy: 0.8086 - loss: 0.4484 - val_Accuracy: 0.8000 - val_loss: 0.5122
# Epoch 4/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - Accuracy: 0.7984 - loss: 0.4379 - val_Accuracy: 0.8000 - val_loss: 0.5105
# Epoch 5/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - Accuracy: 0.7945 - loss: 0.4405 - val_Accuracy: 0.8000 - val_loss: 0.5089
# Epoch 6/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - Accuracy: 0.7789 - loss: 0.4451 - val_Accuracy: 0.8000 - val_loss: 0.5073
# Epoch 7/200
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - Accuracy: 0.7984 - loss: 0.4285 - val_Accuracy: 0.8000 - val_loss: 0.5058
# Epoch 8/200
# ...

# %%
history1.history.keys()
# Out:
# dict_keys(['Accuracy', 'loss', 'val_Accuracy', 'val_loss'])

# %%
plt.plot(history1.history['Accuracy'])
plt.plot(history2.history['Accuracy'])
